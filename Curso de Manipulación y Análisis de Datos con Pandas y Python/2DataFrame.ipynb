# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
dic= {'co':100,'mex':200,'chi':300}

# %%
dic
# Out:
# {'co': 100, 'mex': 200, 'chi': 300}

# %%
type(dic)
# Out:
# dict

# %%
pd.Series(dic)
# Out:
# co     100
# mex    200
# chi    300
# dtype: int64

# %%
dicdata={'co':[100,200,300],'mex':[400,500,600],'chi':[700,800,800]}

# %%
dicdata
# Out:
# {'co': [100, 200, 300], 'mex': [400, 500, 600], 'chi': [700, 800, 800]}

# %%
pd.DataFrame(dicdata)
# Out:
#     co  mex  chi
# 0  100  400  700
# 1  200  500  800
# 2  300  600  800

# %%
import numpy as np
dict_data={
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,124,120,124],
    'pais': ['col','mx','col','mx','mx','ch','ch'],
    'genero': ['m','f','f','m','m','m','f'],
    'q1': [5,10,8,np.nan,7,8,3],
    'q2': [7,9,9,8,8,8,9]
}

# %%
dict_data
# Out:
# {'edad': [10, 9, 13, 14, 12, 11, 12],
#  'cm': [115, 110, 130, 155, 124, 120, 124],
#  'pais': ['col', 'mx', 'col', 'mx', 'mx', 'ch', 'ch'],
#  'genero': ['m', 'f', 'f', 'm', 'm', 'm', 'f'],
#  'q1': [5, 10, 8, nan, 7, 8, 3],
#  'q2': [7, 9, 9, 8, 8, 8, 9]}

# %%
df = pd.DataFrame(dict_data)

# %%
df
# Out:
#    edad   cm pais genero    q1  q2
# 0    10  115  col      m   5.0   7
# 1     9  110   mx      f  10.0   9
# 2    13  130  col      f   8.0   9
# 3    14  155   mx      m   NaN   8
# 4    12  124   mx      m   7.0   8
# 5    11  120   ch      m   8.0   8
# 6    12  124   ch      f   3.0   9

# %%
df_name = pd.DataFrame(dict_data, index=['juan','pedro','jorge','rosa','luis','ana','carmen'])

# %%
df_name
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
df_name.columns
# Out:
# Index(['edad', 'cm', 'pais', 'genero', 'q1', 'q2'], dtype='object')

# %%
df_name.values
# Out:
# array([[10, 115, 'col', 'm', 5.0, 7],
#        [9, 110, 'mx', 'f', 10.0, 9],
#        [13, 130, 'col', 'f', 8.0, 9],
#        [14, 155, 'mx', 'm', nan, 8],
#        [12, 124, 'mx', 'm', 7.0, 8],
#        [11, 120, 'ch', 'm', 8.0, 8],
#        [12, 124, 'ch', 'f', 3.0, 9]], dtype=object)

# %%
df_name["edad"]
# Out:
# juan      10
# pedro      9
# jorge     13
# rosa      14
# luis      12
# ana       11
# carmen    12
# Name: edad, dtype: int64

# %%
df_name["pais"]
# Out:
# juan      col
# pedro      mx
# jorge     col
# rosa       mx
# luis       mx
# ana        ch
# carmen     ch
# Name: pais, dtype: object

# %%
df[['edad', 'cm']]
# Out:
#    edad   cm
# 0    10  115
# 1     9  110
# 2    13  130
# 3    14  155
# 4    12  124
# 5    11  120
# 6    12  124

# %%
df_name[['edad','cm','q1']]
# Out:
#         edad   cm    q1
# juan      10  115   5.0
# pedro      9  110  10.0
# jorge     13  130   8.0
# rosa      14  155   NaN
# luis      12  124   7.0
# ana       11  120   8.0
# carmen    12  124   3.0

# %%
df_name.loc['ana',['edad','cm']]
# Out:
# edad     11
# cm      120
# Name: ana, dtype: object

# %%
df_name.loc[['ana','juan'],['edad','cm']]
# Out:
#       edad   cm
# ana     11  120
# juan    10  115

# %%
#funcion iloc filtrar losdatos por posiion
df_name.iloc[2,1]
# Out:
# 130

# %%
#los dos puntos significan que no straen todos los registros de nommbre
df_name.iloc[:,[1,3]] de la colmna
# Out:
#   Input In [25]
#     df_name.iloc[:,[1,3]] de la colmna
#                           ^
# SyntaxError: invalid syntax

# %%
#traer elemntos de datos espeificos
df_name.iloc[[1,2],[1,2]]
# Out:
#         cm pais
# pedro  110   mx
# jorge  130  col

# %%
df_name['edad']>=12
# Out:
# juan      False
# pedro     False
# jorge      True
# rosa       True
# luis       True
# ana       False
# carmen     True
# Name: edad, dtype: bool

# %%
df_name
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %% [markdown]
# df_name[df_name['edad']>=12]

# %%
#los mayores de edad doce
df_name[df_name['edad']>=12]
# Out:
#         edad   cm pais genero   q1  q2
# jorge     13  130  col      f  8.0   9
# rosa      14  155   mx      m  NaN   8
# luis      12  124   mx      m  7.0   8
# carmen    12  124   ch      f  3.0   9

# %%
df_name[(df_name['edad']>=12) & (df_name['pais']=='mx') ]
# Out:
#       edad   cm pais genero   q1  q2
# rosa    14  155   mx      m  NaN   8
# luis    12  124   mx      m  7.0   8

# %%
df_name.query('edad>13')
# Out:
#       edad   cm pais genero  q1  q2
# rosa    14  155   mx      m NaN   8

# %%
df
# Out:
#    edad   cm pais genero    q1  q2
# 0    10  115  col      m   5.0   7
# 1     9  110   mx      f  10.0   9
# 2    13  130  col      f   8.0   9
# 3    14  155   mx      m   NaN   8
# 4    12  124   mx      m   7.0   8
# 5    11  120   ch      m   8.0   8
# 6    12  124   ch      f   3.0   9

# %%
df_name
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
df.query('edad<12')
# Out:
#    edad   cm pais genero    q1  q2
# 0    10  115  col      m   5.0   7
# 1     9  110   mx      f  10.0   9
# 5    11  120   ch      m   8.0   8

# %%
df.query('edad==12')
# Out:
#    edad   cm pais genero   q1  q2
# 4    12  124   mx      m  7.0   8
# 6    12  124   ch      f  3.0   9

# %%
df_name[df_name['q2']<=df_name['q1']]
# Out:
#        edad   cm pais genero    q1  q2
# pedro     9  110   mx      f  10.0   9
# ana      11  120   ch      m   8.0   8

# %%
'hola {}'.format('como andas')
# Out:
# 'hola como andas'

# %%
dir_pandas='jk10s/{}'.format('test.csv')

# %%
dir_pandas
# Out:
# 'jk10s/test.csv'

# %%
df_name
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
df_name.to_csv(dir_pandas)

# %%
# !ls jk10s
# Out:
# archivo_hoja.xlsx  archivo.json  archivo.xlsx  ml.csv  test.csv  t.hdf	t.pkl

# %%
direc_pandas='jk10s/{}'

# %%
direc_pandas
# Out:
# 'jk10s/{}'

# %%
df_name.to_excel(direc_pandas.format('archivo.xlsx'))

# %%
pd.read_excel(direc_pandas.format('archivo.xlsx'))
# Out:
#   Unnamed: 0  edad   cm pais genero    q1  q2
# 0       juan    10  115  col      m   5.0   7
# 1      pedro     9  110   mx      f  10.0   9
# 2      jorge    13  130  col      f   8.0   9
# 3       rosa    14  155   mx      m   NaN   8
# 4       luis    12  124   mx      m   7.0   8
# 5        ana    11  120   ch      m   8.0   8
# 6     carmen    12  124   ch      f   3.0   9

# %%
df_name.to_excel(direc_pandas.format('archivo_hoja.xlsx', index=False, sheet_nmae='hoja_uno'))

# %%
pd.read_json(direc_pandas.format('archivo.json'))
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
df_name.to_pickle(direc_pandas.format('t.pkl'))

# %%
pd.read_pickle(direc_pandas.format('t.pkl'))
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
df_name.to_hdf(direc_pandas.format('t.hdf'), key='data',format='table')

# %%
pd.read_hdf(direc_pandas.format('t.hdf'))
# Out:
#         edad   cm pais genero    q1  q2
# juan      10  115  col      m   5.0   7
# pedro      9  110   mx      f  10.0   9
# jorge     13  130  col      f   8.0   9
# rosa      14  155   mx      m   NaN   8
# luis      12  124   mx      m   7.0   8
# ana       11  120   ch      m   8.0   8
# carmen    12  124   ch      f   3.0   9

# %%
#df_name.to_parquet(direc_pandas.format('archi.parquet'))

# %%
df_name.nunique()
# Out:
# edad      6
# cm        6
# pais      3
# genero    2
# q1        5
# q2        3
# dtype: int64

# %% [markdown]
# df_name[['edad','nametype']]

# %%
#df_name[['edad','nametype']].astype('category')

# %%
m=pd.read_csv(direc_pandas.format('ml.csv'))

# %%
m.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
m
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
m.tail(2)
# Out:
#              name     id nametype recclass  mass (g)   fall  \
# 45714   Zubkovsky  31357    Valid       L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid     L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %%
m.sample(3)
# Out:
#                           name     id nametype recclass  mass (g)   fall  \
# 1503                 Acfer 390  44855    Valid       H4     578.0  Found
# 31569  Pecora Escarpment 91085  18376    Valid      EH3      79.6  Found
# 10915   Elephant Moraine 90896   9305    Valid       H5      13.9  Found
#
#                          year    reclat    reclong            GeoLocation
# 1503   01/01/2004 12:00:00 AM  27.50250    3.69300       (27.5025, 3.693)
# 31569  01/01/1991 12:00:00 AM -85.65094  -69.08100   (-85.65094, -69.081)
# 10915  01/01/1990 12:00:00 AM -76.28060  156.49971  (-76.2806, 156.49971)

# %%
m.convert_dtypes().dtypes
# Out:
# name            string
# id               Int64
# nametype        string
# recclass        string
# mass (g)       Float64
# fall            string
# year            string
# reclat         Float64
# reclong        Float64
# GeoLocation     string
# dtype: object

# %%
m.nunique()
# Out:
# name           45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12576
# fall               2
# year             266
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
m[['fall','nametype']]
# Out:
#         fall nametype
# 0       Fell    Valid
# 1       Fell    Valid
# 2       Fell    Valid
# 3       Fell    Valid
# 4       Fell    Valid
# ...      ...      ...
# 45711  Found    Valid
# 45712  Found    Valid
# 45713  Found    Valid
# 45714  Found    Valid
# 45715  Found    Valid
#
# [45716 rows x 2 columns]

# %%
m[['fall','nametype']]=m[['fall','nametype']].astype('category')

# %%
m.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year             object
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
m['fall'].unique()
# Out:
# ['Fell', 'Found']
# Categories (2, object): ['Fell', 'Found']

# %%
#m['fall'].value.counts()

# %%
pd.get_dummies(m['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
m['ones']=1

# %%
m
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation  \
# ...

# %%
m[['fell','found']]=pd.get_dummies(m['fall'])

# %%
m
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation  \
# ...

# %%
m['year']
# Out:
# 0        01/01/1880 12:00:00 AM
# 1        01/01/1951 12:00:00 AM
# 2        01/01/1952 12:00:00 AM
# 3        01/01/1976 12:00:00 AM
# 4        01/01/1902 12:00:00 AM
#                   ...
# 45711    01/01/1990 12:00:00 AM
# 45712    01/01/1999 12:00:00 AM
# 45713    01/01/1939 12:00:00 AM
# 45714    01/01/2003 12:00:00 AM
# 45715    01/01/1976 12:00:00 AM
# Name: year, Length: 45716, dtype: object

# %%
pd.to_datetime(
m['year'],
     errors = 'coerce',
     format = '%m/%d/%Y %H:%M:%S %p'
)
# Out:
# 0       1880-01-01 12:00:00
# 1       1951-01-01 12:00:00
# 2       1952-01-01 12:00:00
# 3       1976-01-01 12:00:00
# 4       1902-01-01 12:00:00
#                 ...
# 45711   1990-01-01 12:00:00
# 45712   1999-01-01 12:00:00
# 45713   1939-01-01 12:00:00
# 45714   2003-01-01 12:00:00
# 45715   1976-01-01 12:00:00
# Name: year, Length: 45716, dtype: datetime64[ns]

# %%
pd.to_datetime(
m['year'],
errors = 'coerce',
format = '%m/%d/%Y %H:%M:%S %p'
)
# Out:
# 0       1880-01-01 12:00:00
# 1       1951-01-01 12:00:00
# 2       1952-01-01 12:00:00
# 3       1976-01-01 12:00:00
# 4       1902-01-01 12:00:00
#                 ...
# 45711   1990-01-01 12:00:00
# 45712   1999-01-01 12:00:00
# 45713   1939-01-01 12:00:00
# 45714   2003-01-01 12:00:00
# 45715   1976-01-01 12:00:00
# Name: year, Length: 45716, dtype: datetime64[ns]

# %%
m['year']=pd.to_datetime(
m['year'],
     errors = 'coerce',
     format = '%m/%d/%Y %H:%M:%S %p'
)

# %%
m.dtypes
# Out:
# name                   object
# id                      int64
# nametype             category
# recclass               object
# mass (g)              float64
# fall                 category
# year           datetime64[ns]
# reclat                float64
# reclong               float64
# GeoLocation            object
# ones                    int64
# fell                    uint8
# found                   uint8
# dtype: object

# %%
m.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation', 'ones', 'fell', 'found'],
#       dtype='object')

# %%
m.rename(columns={'mass (g)':'masss'},inplace=True)

# %%
m
# Out:
#              name     id nametype              recclass     masss   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year    reclat    reclong             GeoLocation  ones  \
# ...

# %% [markdown]
# borrar celdas fulilas columnas

# %%
list(m)
# Out:
# ['name',
#  'id',
#  'nametype',
#  'recclass',
#  'masss',
#  'fall',
#  'year',
#  'reclat',
#  'reclong',
#  'GeoLocation',
#  'ones',
#  'fell',
#  'found']

# %%
 #codigo para eliminar a columna ones el axis o para indice y 1 para columna

m.drop(['ones'], axis=1, inplace=True)

# %%
m.head(5)
# Out:
#        name   id nametype     recclass     masss  fall                year  \
# 0    Aachen    1    Valid           L5      21.0  Fell 1880-01-01 12:00:00
# 1    Aarhus    2    Valid           H6     720.0  Fell 1951-01-01 12:00:00
# 2      Abee    6    Valid          EH4  107000.0  Fell 1952-01-01 12:00:00
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell 1976-01-01 12:00:00
# 4   Achiras  370    Valid           L6     780.0  Fell 1902-01-01 12:00:00
#
#      reclat    reclong           GeoLocation  fell  found
# 0  50.77500    6.08333     (50.775, 6.08333)     1      0
# 1  56.18333   10.23333  (56.18333, 10.23333)     1      0
# 2  54.21667 -113.00000    (54.21667, -113.0)     1      0
# 3  16.88333  -99.90000     (16.88333, -99.9)     1      0
# 4 -33.16667  -64.95000   (-33.16667, -64.95)     1      0

# %%
m
# Out:
#              name     id nametype              recclass     masss   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year    reclat    reclong             GeoLocation  fell  \
# ...

# %%
#eliminar filas por indices
m.drop([0,2,4,6])
# Out:
#              name     id nametype              recclass    masss   fall  \
# 1          Aarhus      2    Valid                    H6    720.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1914.0   Fell
# 5        Adhi Kot    379    Valid                   EH4   4239.0   Fell
# 7            Agen    392    Valid                    H5  30000.0   Fell
# 8          Aguada    398    Valid                    L6   1620.0   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite    172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped     46.0  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7    200.0  Found
#
#                      year    reclat    reclong             GeoLocation  fell  \
# ...

# %%
m.drop(index=[1,2,3,4]).head(6)
# Out:
#                   name   id nametype recclass    masss  fall  \
# 0               Aachen    1    Valid       L5     21.0  Fell
# 5             Adhi Kot  379    Valid      EH4   4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid    LL3-6    910.0  Fell
# 7                 Agen  392    Valid       H5  30000.0  Fell
# 8               Aguada  398    Valid       L6   1620.0  Fell
# 9        Aguila Blanca  417    Valid        L   1440.0  Fell
#
#                  year    reclat   reclong           GeoLocation  fell  found
# 0 1880-01-01 12:00:00  50.77500   6.08333     (50.775, 6.08333)     1      0
# 5 1919-01-01 12:00:00  32.10000  71.80000          (32.1, 71.8)     1      0
# 6 1949-01-01 12:00:00  44.83333  95.16667  (44.83333, 95.16667)     1      0
# 7 1814-01-01 12:00:00  44.21667   0.61667   (44.21667, 0.61667)     1      0
# 8 1930-01-01 12:00:00 -31.60000 -65.23333    (-31.6, -65.23333)     1      0
# 9 1920-01-01 12:00:00 -30.86667 -64.55000   (-30.86667, -64.55)     1      0

# %%
#eliminar filas y columnas alvez
m.drop(columns=['id','recclass'],index=[1,2,3,4]).head(6)
# Out:
#                   name nametype    masss  fall                year    reclat  \
# 0               Aachen    Valid     21.0  Fell 1880-01-01 12:00:00  50.77500
# 5             Adhi Kot    Valid   4239.0  Fell 1919-01-01 12:00:00  32.10000
# 6  Adzhi-Bogdo (stone)    Valid    910.0  Fell 1949-01-01 12:00:00  44.83333
# 7                 Agen    Valid  30000.0  Fell 1814-01-01 12:00:00  44.21667
# 8               Aguada    Valid   1620.0  Fell 1930-01-01 12:00:00 -31.60000
# 9        Aguila Blanca    Valid   1440.0  Fell 1920-01-01 12:00:00 -30.86667
#
#     reclong           GeoLocation  fell  found
# 0   6.08333     (50.775, 6.08333)     1      0
# 5  71.80000          (32.1, 71.8)     1      0
# 6  95.16667  (44.83333, 95.16667)     1      0
# 7   0.61667   (44.21667, 0.61667)     1      0
# 8 -65.23333    (-31.6, -65.23333)     1      0
# 9 -64.55000   (-30.86667, -64.55)     1      0

# %%
#hacer coopi profunda
df_ = m.copy(deep=True)

# %%
df_
# Out:
#              name     id nametype              recclass     masss   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year    reclat    reclong             GeoLocation  fell  \
# ...

# %%
#primero 5 regstros
m.head(5)
# Out:
#        name   id nametype     recclass     masss  fall                year  \
# 0    Aachen    1    Valid           L5      21.0  Fell 1880-01-01 12:00:00
# 1    Aarhus    2    Valid           H6     720.0  Fell 1951-01-01 12:00:00
# 2      Abee    6    Valid          EH4  107000.0  Fell 1952-01-01 12:00:00
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell 1976-01-01 12:00:00
# 4   Achiras  370    Valid           L6     780.0  Fell 1902-01-01 12:00:00
#
#      reclat    reclong           GeoLocation  fell  found
# 0  50.77500    6.08333     (50.775, 6.08333)     1      0
# 1  56.18333   10.23333  (56.18333, 10.23333)     1      0
# 2  54.21667 -113.00000    (54.21667, -113.0)     1      0
# 3  16.88333  -99.90000     (16.88333, -99.9)     1      0
# 4 -33.16667  -64.95000   (-33.16667, -64.95)     1      0

# %%
#ver los ultimo s5 registros 
m.tail(5)
# Out:
#              name     id nametype              recclass   masss   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite   172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped    46.0  Found
# 45713        Zlin  30410    Valid                    H4     3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6  2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7   200.0  Found
#
#                      year    reclat    reclong             GeoLocation  fell  \
# 45711 1990-01-01 12:00:00  29.03700   17.01850       (29.037, 17.0185)     0
# 45712 1999-01-01 12:00:00  13.78333    8.96667     (13.78333, 8.96667)     0
# 45713 1939-01-01 12:00:00  49.25000   17.66667       (49.25, 17.66667)     0
# 45714 2003-01-01 12:00:00  49.78917   41.50460     (49.78917, 41.5046)     0
# 45715 1976-01-01 12:00:00  33.98333 -115.68333  (33.98333, -115.68333)     0
#
#        found
# 45711      1
# 45712      1
# 45713      1
# 45714      1
# ...

# %%
#ver registro aleatorios
m.sample(10)
# Out:
#                               name     id nametype    recclass     masss  \
# 11639                      El-Oued  47729    Valid          H4   2305.00
# 35406  Queen Alexandra Range 99778  22224    Valid         LL5     13.50
# 28845        Northwest Africa 4642  45584    Valid  Enst achon    483.20
# 17382                 Kramer Creek  12354    Valid          L4   2300.00
# 35275  Queen Alexandra Range 99648  22094    Valid         LL5     18.30
# 3554                   Asuka 87161   2518    Valid          H5    106.46
# 591                  Marion (Iowa)  15424    Valid          L6  28400.00
# 25371          Miller Range 090294  55923    Valid         CK5     10.00
# 27586        Northwest Africa 2548  31111    Valid          H4     28.80
# 27483        Northwest Africa 2450  33056    Valid        H4-6    766.00
#
#         fall                year     reclat     reclong  \
# 11639  Found 1952-01-01 12:00:00  31.533333    8.883333
# ...

# %%
m.describe()
# Out:
#                  id         masss        reclat       reclong          fell  \
# count  45716.000000  4.558500e+04  38401.000000  38401.000000  45716.000000
# mean   26889.735104  1.327808e+04    -39.122580     61.074319      0.024215
# std    16860.683030  5.749889e+05     46.378511     80.647298      0.153717
# min        1.000000  0.000000e+00    -87.366670   -165.433330      0.000000
# 25%    12688.750000  7.200000e+00    -76.714240      0.000000      0.000000
# 50%    24261.500000  3.260000e+01    -71.500000     35.666670      0.000000
# 75%    40656.750000  2.026000e+02      0.000000    157.166670      0.000000
# max    57458.000000  6.000000e+07     81.166670    354.473330      1.000000
#
#               found
# count  45716.000000
# mean       0.975785
# std        0.153717
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
m.describe(include='all')
# Out:
# /tmp/ipykernel_17713/2903499825.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   m.describe(include='all')
#           name            id nametype recclass         masss   fall  \
# count    45716  45716.000000    45716    45716  4.558500e+04  45716
# unique   45716           NaN        2      466           NaN      2
# top     Aachen           NaN    Valid       L6           NaN  Found
# freq         1           NaN    45641     8285           NaN  44609
# first      NaN           NaN      NaN      NaN           NaN    NaN
# last       NaN           NaN      NaN      NaN           NaN    NaN
# mean       NaN  26889.735104      NaN      NaN  1.327808e+04    NaN
# std        NaN  16860.683030      NaN      NaN  5.749889e+05    NaN
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  category
#  3   recclass     45716 non-null  object
#  4   masss        45585 non-null  float64
#  5   fall         45716 non-null  category
#  6   year         45404 non-null  datetime64[ns]
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
#  10  fell         45716 non-null  uint8
#  11  found        45716 non-null  uint8
# dtypes: category(2), datetime64[ns](1), float64(3), int64(1), object(3), uint8(2)
# memory usage: 3.0+ MB

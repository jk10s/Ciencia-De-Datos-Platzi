# %%
import pandas as pd

# %%
df = pd.read_csv("jk10s/Meteorite_Landings .csv")

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
df.loc[0,"id"]
# Out:
# 1

# %%
df.head(40)
# Out:
#                       name     id nametype       recclass   mass (g)   fall  \
# 0                   Aachen      1    Valid             L5       21.0   Fell
# 1                   Aarhus      2    Valid             H6      720.0   Fell
# 2                     Abee      6    Valid            EH4   107000.0   Fell
# 3                 Acapulco     10    Valid    Acapulcoite     1914.0   Fell
# 4                  Achiras    370    Valid             L6      780.0   Fell
# 5                 Adhi Kot    379    Valid            EH4     4239.0   Fell
# 6      Adzhi-Bogdo (stone)    390    Valid          LL3-6      910.0   Fell
# 7                     Agen    392    Valid             H5    30000.0   Fell
# 8                   Aguada    398    Valid             L6     1620.0   Fell
# 9            Aguila Blanca    417    Valid              L     1440.0   Fell
# 10        Aioun el Atrouss    423    Valid   Diogenite-pm     1000.0   Fell
# ...

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df[["nametype","fall"]]=df[["nametype","fall"]].astype('category')

# %%
df.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year             object
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
df['fall'].unique()
# Out:
# ['Fell', 'Found']
# Categories (2, object): ['Fell', 'Found']

# %%
df['fall'].value_counts()
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
pd.get_dummies(df['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
df['ones']=1

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation  \
# ...

# %%
df[['fell','found']]= pd.get_dummies(df['fall'])

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation  \
# ...

# %%
df.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year             object
# reclat          float64
# reclong         float64
# GeoLocation      object
# ones              int64
# fell              uint8
# found             uint8
# dtype: object

# %%
df['year']= pd.to_datetime(
df['year'],
errors='coerce',
format='%m/%d/%y %H:%S %p'
)

# %%
df.dtypes
# Out:
# name                   object
# id                      int64
# nametype             category
# recclass               object
# mass (g)              float64
# fall                 category
# year           datetime64[ns]
# reclat                float64
# reclong               float64
# GeoLocation            object
# ones                    int64
# fell                    uint8
# found                   uint8
# dtype: object

# %%
df.rename(columns={'mass (g)':'maas'},inplace=True)

# %%
df
# Out:
#              name     id nametype              recclass      maas   fall year  \
# 0          Aachen      1    Valid                    L5      21.0   Fell  NaT
# 1          Aarhus      2    Valid                    H6     720.0   Fell  NaT
# 2            Abee      6    Valid                   EH4  107000.0   Fell  NaT
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell  NaT
# 4         Achiras    370    Valid                    L6     780.0   Fell  NaT
# ...           ...    ...      ...                   ...       ...    ...  ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found  NaT
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found  NaT
# 45713        Zlin  30410    Valid                    H4       3.3  Found  NaT
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found  NaT
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found  NaT
#
# ...

# %%
#nombre de las columnas
list(df)
# Out:
# ['name',
#  'id',
#  'nametype',
#  'recclass',
#  'maas',
#  'fall',
#  'year',
#  'reclat',
#  'reclong',
#  'GeoLocation',
#  'ones',
#  'fell',
#  'found']

# %%
df.drop(['ones'],axis=1,inplace=True)

# %%
df
# Out:
#              name     id nametype              recclass      maas   fall year  \
# 0          Aachen      1    Valid                    L5      21.0   Fell  NaT
# 1          Aarhus      2    Valid                    H6     720.0   Fell  NaT
# 2            Abee      6    Valid                   EH4  107000.0   Fell  NaT
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell  NaT
# 4         Achiras    370    Valid                    L6     780.0   Fell  NaT
# ...           ...    ...      ...                   ...       ...    ...  ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found  NaT
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found  NaT
# 45713        Zlin  30410    Valid                    H4       3.3  Found  NaT
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found  NaT
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found  NaT
#
# ...

# %%
#elimina las filas 2 4 6
df.drop([0,2,4,6])
# Out:
#              name     id nametype              recclass     maas   fall year  \
# 1          Aarhus      2    Valid                    H6    720.0   Fell  NaT
# 3        Acapulco     10    Valid           Acapulcoite   1914.0   Fell  NaT
# 5        Adhi Kot    379    Valid                   EH4   4239.0   Fell  NaT
# 7            Agen    392    Valid                    H5  30000.0   Fell  NaT
# 8          Aguada    398    Valid                    L6   1620.0   Fell  NaT
# ...           ...    ...      ...                   ...      ...    ...  ...
# 45711  Zillah 002  31356    Valid               Eucrite    172.0  Found  NaT
# 45712      Zinder  30409    Valid  Pallasite, ungrouped     46.0  Found  NaT
# 45713        Zlin  30410    Valid                    H4      3.3  Found  NaT
# 45714   Zubkovsky  31357    Valid                    L6   2167.0  Found  NaT
# 45715  Zulu Queen  30414    Valid                  L3.7    200.0  Found  NaT
#
# ...

# %%
j=df.drop(columns=['nametype'])

# %%
j
# Out:
#              name     id              recclass      maas   fall year  \
# 0          Aachen      1                    L5      21.0   Fell  NaT
# 1          Aarhus      2                    H6     720.0   Fell  NaT
# 2            Abee      6                   EH4  107000.0   Fell  NaT
# 3        Acapulco     10           Acapulcoite    1914.0   Fell  NaT
# 4         Achiras    370                    L6     780.0   Fell  NaT
# ...           ...    ...                   ...       ...    ...  ...
# 45711  Zillah 002  31356               Eucrite     172.0  Found  NaT
# 45712      Zinder  30409  Pallasite, ungrouped      46.0  Found  NaT
# 45713        Zlin  30410                    H4       3.3  Found  NaT
# 45714   Zubkovsky  31357                    L6    2167.0  Found  NaT
# 45715  Zulu Queen  30414                  L3.7     200.0  Found  NaT
#
#          reclat    reclong             GeoLocation  fell  found
# 0      50.77500    6.08333       (50.775, 6.08333)     1      0
# ...

# %%
df
# Out:
#              name     id nametype              recclass      maas   fall year  \
# 0          Aachen      1    Valid                    L5      21.0   Fell  NaT
# 1          Aarhus      2    Valid                    H6     720.0   Fell  NaT
# 2            Abee      6    Valid                   EH4  107000.0   Fell  NaT
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell  NaT
# 4         Achiras    370    Valid                    L6     780.0   Fell  NaT
# ...           ...    ...      ...                   ...       ...    ...  ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found  NaT
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found  NaT
# 45713        Zlin  30410    Valid                    H4       3.3  Found  NaT
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found  NaT
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found  NaT
#
# ...

# %% [raw]
# df.drop(['id',axis=1,inplace=True])

# %%
df.drop(columns=['id'],axis=1,inplace=True)

# %%
df
# Out:
#              name nametype              recclass      maas   fall year  \
# 0          Aachen    Valid                    L5      21.0   Fell  NaT
# 1          Aarhus    Valid                    H6     720.0   Fell  NaT
# 2            Abee    Valid                   EH4  107000.0   Fell  NaT
# 3        Acapulco    Valid           Acapulcoite    1914.0   Fell  NaT
# 4         Achiras    Valid                    L6     780.0   Fell  NaT
# ...           ...      ...                   ...       ...    ...  ...
# 45711  Zillah 002    Valid               Eucrite     172.0  Found  NaT
# 45712      Zinder    Valid  Pallasite, ungrouped      46.0  Found  NaT
# 45713        Zlin    Valid                    H4       3.3  Found  NaT
# 45714   Zubkovsky    Valid                    L6    2167.0  Found  NaT
# 45715  Zulu Queen    Valid                  L3.7     200.0  Found  NaT
#
#          reclat    reclong             GeoLocation  fell  found
# ...
